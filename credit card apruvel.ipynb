# %% [markdown]
# #                                        Predict credit card approval

# %% [markdown]
# ### Introduction

# %% [markdown]
# Credit cards are widely used financial tools, but getting approved for one can be challenging due to factors like income and employment status. To make the application process smoother and enhance approval rates, machine learning models can be employed. These models predict the likelihood of credit card approval by considering different factors. In this project, we aim to understand how various factors influence credit card approval rates and use predictive models to improve the accuracy of these predictions."

# %% [markdown]
# Attribute Descriptions
#
# Gender: This column indicates the gender of the individual, either male or female. It is a Categorical (binary).
#
# Car_Owner: This column indicates whether the individual owns a car or not, either Yes or No.It is a Categorical (binary).
#
# Propert_Owner: This column indicates whether the individual owns a property or not, either Yes or No.It is a Categorical (binary).
#
# Children: This column indicates the number of children the individual has.It is a Numerical(integer).
#
# Annual_income: This column contains the annual income of the individual.It is a Numerical (continuous).
#
# Type_Income: This column indicates the type of income the individual earns, such as salary or self-employed income.It is a Numerical (nominal).
#
# Education: This column indicates the level of education of the individual. It is a Categorical (ordinal).
#
# Marital_status: This column indicates the marital status of the individual, such as Single, Married, Divorced, etc. It is a Categorical (nominal).
#
# Housing_type: This column indicates the type of housing the individual lives in, such as a house or apartment. It is a Categorical (nominal).
#
# Birthday_count: This column contains the age of the individual.It is a Numerical(integer).
#
# Employed_days: This column indicates the number of days the individual has been employed.It is a Numerical(integer).
#
# Mobile_phone, Work_Phone, Phone, and Email_id: These columns contain contact information for the individual, such as mobile phone number, work phone number, home phone number, and email id.Mobile_phone, Work_Phone, Phone are Categorical (binary) and Email_id is Categorical (nominal).
#
# Type_Occupation: This column indicates the type of occupation of the individual, such as healthcare or education. It is a Categorical (nominal).
#
# Family_Members: This column indicates the number of family members the individual has.It is a Numeric (integer).
#
# Label: This column contains the label for credit card approval, either approved or not approved. It is a Categorical (binary).

# %% [markdown]
# #### 1) Why is your proposal important in today’s world? How predicting a good client is worthy for a bank?

# %% [markdown]
# The proposal to develop a predictive model for credit card approval holds significant relevance in the contemporary financial landscape, driven by the widespread adoption of credit cards as a pivotal financial instrument. Given the escalating prevalence of e-commerce and online transactions, credit cards have emerged as a predominant method of payment, necessitating banks to optimize the credit card application process and enhance approval rates.
#
# Accurate prediction of creditworthiness is imperative for banks as it facilitates the mitigation of credit default risks and reduces the operational costs associated with managing credit card accounts. Leveraging machine learning algorithms enables thorough analysis of pertinent factors such as income levels, employment statuses, and more. Precise predictions empower banks to extend credit card offerings to clients with lower risk profiles, thereby fostering improved profitability and heightened customer satisfaction.

# %% [markdown]
# c

# %% [markdown]
# Utilizing machine learning for credit card approval prediction holds transformative potential within the banking sector, manifesting in enhanced customer experience, risk mitigation, and increased profitability.
#
# Enhanced Customer Experience:
#
# Leveraging predictive models facilitates expedited and precise credit card approval processes, contributing to an elevated customer experience.
# Accelerated approval timelines and heightened accuracy contribute to heightened customer satisfaction and foster customer loyalty.
# Risk Mitigation of Credit Defaults:
#
# Machine learning algorithms play a pivotal role in accurately forecasting the probability of clients defaulting on credit card payments.
# Identification of clients with lower credit risk profiles enables banks to offer credit cards with reduced interest rates, effectively mitigating the risk of defaults and bolstering overall profitability.
# Improved Profitability:
#
# Through the reduction of credit default risks and optimization of underwriting procedures, banks can bolster their profitability.
# Enhanced operational efficiency allows for the provision of favorable rates and benefits to clients, thereby expanding market share and augmenting revenue streams.

# %% [markdown]
# #### 3) If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India.

# %% [markdown]
# A) The implementation of the proposed methodology can address knowledge or process gaps inherent in credit card approval practices within Indian banking institutions. This approach stands to enhance the precision of credit card approval predictions, fortify credit risk management strategies, and optimize operational efficiency. To maximize the efficacy of our proposed method, it is imperative for banks to establish access to robust and comprehensive data sources, ensuring the availability of reliable information for informed decision-making.

# %% [markdown]
# ## Data cleaning

# %%
# There are two tables credit card and credit card lebel import the data merge the table

# %%
#import lib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\star\Desktop\Credit_card.csv")
df.head(6)
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
# 5  5009753    NaN         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
# ...

# %%
df1=pd.read_csv(r"C:\Users\star\Desktop\Credit_card_label.csv")
df1
# Out:
#        Ind_ID  label
# 0     5008827      1
# 1     5009744      1
# 2     5009746      1
# 3     5009749      1
# 4     5009752      1
# ...       ...    ...
# 1543  5028645      0
# 1544  5023655      0
# 1545  5115992      0
# 1546  5118219      0
# 1547  5053790      0
#
# [1548 rows x 2 columns]

# %%
df3 = pd.merge(df, df1, on='Ind_ID')
df3
# Out:
#        Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0     5008827      M         Y             Y         0       180000.0
# 1     5009744      F         Y             N         0       315000.0
# 2     5009746      F         Y             N         0       315000.0
# 3     5009749      F         Y             N         0            NaN
# 4     5009752      F         Y             N         0       315000.0
# ...       ...    ...       ...           ...       ...            ...
# 1543  5028645      F         N             Y         0            NaN
# 1544  5023655      F         N             N         0       225000.0
# 1545  5115992      M         Y             Y         2       180000.0
# 1546  5118219      M         Y             N         0       270000.0
# 1547  5053790      F         Y             Y         0       225000.0
#
#                Type_Income                      EDUCATION  \
# 0                Pensioner               Higher education
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
df3.isnull().sum()
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
# data is unorganised and also contain sum missing value
for i in df3:
  print(i, ":", df3[i].unique())
# Out:
# Gender : [0 1]
# Car_Owner : [0 1]
# Propert_Owner : [0 1]
# Children : [0 1 2 4 3]
# Annual_income : [180000.0 315000.0 '135000' 450000.0 90000.0 472500.0 270000.0 126000.0
#  202500.0 157500.0 112500.0 540000.0 292500.0 135000.0 76500.0 215100.0
#  225000.0 67500.0 171000.0 103500.0 99000.0 391500.0 65250.0 72900.0
#  360000.0 256500.0 675000.0 247500.0 85500.0 121500.0 130500.0 211500.0
#  81000.0 72000.0 148500.0 162000.0 195750.0 585000.0 216000.0 306000.0
#  108000.0 63000.0 45000.0 337500.0 131400.0 117000.0 445500.0 234000.0
#  1575000.0 144000.0 67050.0 73350.0 193500.0 900000.0 94500.0 198000.0
#  54000.0 166500.0 167400.0 153000.0 423000.0 243000.0 283500.0 252000.0
#  495000.0 612000.0 36000.0 139500.0 133650.0 427500.0 261000.0 231750.0
#  90900.0 45900.0 119250.0 58500.0 328500.0 787500.0 594000.0 119700.0
#  69372.0 37800.0 387000.0 207000.0 189000.0 333000.0 105750.0 382500.0
#  141750.0 40500.0 405000.0 44550.0 301500.0 351000.0 175500.0 121900.5
# ...

# %%
df3.columns
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members',
#        'label'],
#       dtype='object')

# %%
df3 = df3.rename(columns={'Ind_ID':'Ind_id', 'GENDER': 'Gender', 'CHILDREN': 'Children', 'EDUCATION': 'Education', 'EMAIL_ID':'Email_id','Birthday_count': 'Age','Employed_days':'Employed_exp'})

# %%
df3.describe()
# Out:
#              Ind_id     Children  Annual_income           Age   Employed_exp  \
# count  1.548000e+03  1548.000000   1.525000e+03   1526.000000    1548.000000
# mean   5.078920e+06     0.412791   1.913993e+05 -16040.342071   59364.689922
# std    4.171759e+04     0.776691   1.132530e+05   4229.503202  137808.062701
# min    5.008827e+06     0.000000   3.375000e+04 -24946.000000  -14887.000000
# 25%    5.045070e+06     0.000000   1.215000e+05 -19553.000000   -3174.500000
# 50%    5.078842e+06     0.000000   1.665000e+05 -15661.500000   -1565.000000
# 75%    5.115673e+06     1.000000   2.250000e+05 -12417.000000    -431.750000
# max    5.150412e+06    14.000000   1.575000e+06  -7705.000000  365243.000000
#
#        Mobile_phone   Work_Phone        Phone     Email_id  Family_Members  \
# count        1548.0  1548.000000  1548.000000  1548.000000     1548.000000
# mean            1.0     0.208010     0.309432     0.092377        2.161499
# ...

# %%
import missingno as msno
msno.bar(df3)
# Out:
# <Axes: >

# %%
sns.heatmap(df3.isnull())
# Out:
# <Axes: >

# %%
#fill the null value in column with the mode value of the column 
df3['Gender'].mode()[0]
# Out:
# 'F'

# %%
df3['Gender'].fillna("F", inplace=True)

# %%
df4=df3.copy()

# %%
df3['Children'] = df3['Children'].replace(14, 1)

# %%
df3['Annual_income'].mode()[0]
# Out:
# 135000.0

# %%
df3['Annual_income'].fillna("135000", inplace=True)

# %%
df3['Education'] = df3['Education'].replace('Secondary / secondary special', 'Secondary education')

# %%
# transforming the different marital status into two category Single or Married
df3['Marital_status'] = df3['Marital_status'].replace('Single / not married', 'Single')

# %%
df3['Marital_status'] = df3['Marital_status'].replace('Separated', 'Single')

# %%
df3['Marital_status'] = df3['Marital_status'].replace('Civil marriage', 'Married')

# %%
df3['Marital_status'] = df3['Marital_status'].replace('Widow', 'Single')

# %%
# Transforming aprtment category into two types of Rented apartment or owned apartment 
df3['Housing_type'] = df3['Housing_type'].replace('House / apartment', 'apartment')

# %%
df3['Housing_type'] = df3['Housing_type'].replace('With parents', 'apartment')

# %%
df3['Housing_type'] = df3['Housing_type'].replace('Municipal apartment', 'Rented apartment')

# %%
df3['Housing_type'] = df3['Housing_type'].replace('Co-op apartment', 'Rented apartment')

# %%
df3['Housing_type'] = df3['Housing_type'].replace('Office apartment', 'Rented apartment')

# %%
# converting the negative values to actual age
df3['Age']=abs(round((df3['Age']/-365),0))
# converting negative values to exprience of the employee
df3['Employed_exp']=abs(round((df3['Employed_exp']/-365),0))

# %%
# replacing the extreme values with zero.
df3['Employed_exp'].replace(1001.0, 0,inplace=True)
df3.head()
# Out:
#     Ind_id Gender Car_Owner Propert_Owner  Children Annual_income  \
# 0  5008827      M         Y             Y         0      180000.0
# 1  5009744      F         Y             N         0      315000.0
# 2  5009746      F         Y             N         0      315000.0
# 3  5009749      F         Y             N         0        135000
# 4  5009752      F         Y             N         0      315000.0
#
#             Type_Income         Education Marital_status Housing_type   Age  \
# 0             Pensioner  Higher education        Married    apartment  51.0
# 1  Commercial associate  Higher education        Married    apartment  37.0
# 2  Commercial associate  Higher education        Married    apartment   NaN
# 3  Commercial associate  Higher education        Married    apartment  37.0
# 4  Commercial associate  Higher education        Married    apartment  37.0
#
#    Employed_exp  Mobile_phone  Work_Phone  Phone  Email_id Type_Occupation  \
# ...

# %%
df3['Type_Occupation'].mode()[0]
# Out:
# 'Laborers'

# %%
df3['Type_Occupation'].fillna("Laborers", inplace=True)

# %%
df3['Age'].mode()[0]
# Out:
# 42.0

# %%
df3['Age'].fillna("42", inplace=True)

# %%
# converting the various staff to lower staff 
values_to_replace = ['Laborers', 'Cleaning staff', 'Drivers', 'Low-skill Laborers', 'Waiters/barmen staff', 'Security staff']
replacement_value = 'lower_staff'

df3['Type_Occupation'] = df3['Type_Occupation'].replace(values_to_replace, replacement_value)

# %%
# converting the manager and with the sme level of post 
higher_manager_values = ['Managers', 'HR staff', 'Secretaries', 'Accountants staff']
replacement_value_higher_manager = 'Higher_manager_level'

df3['Type_Occupation'] = df3['Type_Occupation'].replace(higher_manager_values, replacement_value_higher_manager)

# %%
df3['Family_Members'] = df3['Family_Members'].replace(15, 1)

# %%
for i in df3:
  print(i, ":", df3[i].unique())
# Out:
# Ind_id : [5008827 5009744 5009746 ... 5115992 5118219 5053790]
# Gender : ['M' 'F']
# Car_Owner : ['Y' 'N']
# Propert_Owner : ['Y' 'N']
# Children : [0 1 2 4 3]
# Annual_income : [180000.0 315000.0 '135000' 450000.0 90000.0 472500.0 270000.0 126000.0
#  202500.0 157500.0 112500.0 540000.0 292500.0 135000.0 76500.0 215100.0
#  225000.0 67500.0 171000.0 103500.0 99000.0 391500.0 65250.0 72900.0
#  360000.0 256500.0 675000.0 247500.0 85500.0 121500.0 130500.0 211500.0
#  81000.0 72000.0 148500.0 162000.0 195750.0 585000.0 216000.0 306000.0
#  108000.0 63000.0 45000.0 337500.0 131400.0 117000.0 445500.0 234000.0
#  1575000.0 144000.0 67050.0 73350.0 193500.0 900000.0 94500.0 198000.0
#  54000.0 166500.0 167400.0 153000.0 423000.0 243000.0 283500.0 252000.0
#  495000.0 612000.0 36000.0 139500.0 133650.0 427500.0 261000.0 231750.0
#  90900.0 45900.0 119250.0 58500.0 328500.0 787500.0 594000.0 119700.0
#  69372.0 37800.0 387000.0 207000.0 189000.0 333000.0 105750.0 382500.0
# ...

# %% [markdown]
# # Data visulization

# %%
# count number of males and females 
gender_count=df3['Gender'].value_counts()
#creat barpolt using Matplotlib
plt.bar(gender_count.index,gender_count.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender')
plt.show()
# there is feamle customer is more than the male customer

# %%
# count number of car owner
car_owner_count=df3['Car_Owner'].value_counts()
#creat barpolt using Matplotlib
plt.bar(car_owner_count.index,car_owner_count.values)
plt.xlabel('car_owner_count')
plt.ylabel('Count')
plt.title('Distribution of car_owner')
plt.show()
# majority of the person do not buy the car

# %%
# count number of propert_owner
propert_owner_count=df3['Propert_Owner'].value_counts()
#creat barpolt using Matplotlib
plt.bar(propert_owner_count.index,propert_owner_count.values)
plt.xlabel('propert_owner_count')
plt.ylabel('Count')
plt.title('Distribution of propert_owner')
plt.show()
# property is owned by the most of the customer

# %%
# count number of children
children_count=df3['Children'].value_counts()
#creat barpolt using Matplotlib
plt.bar(children_count.index,children_count.values)
plt.xlabel('children_count')
plt.ylabel('count')
plt.title('Distribution of children_count')
plt.show()
# majority of customer do not have the children as they are single, widow , or seperated

# %%
# count number of Type_Income
Type_Income_count=df3['Type_Income'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Type_Income_count.index,Type_Income_count.values)
plt.xlabel('Type_Income')
plt.ylabel('count')
plt.title('Distribution of Type_Income')
plt.show()

# %%
# count number of Education
Education_count=df3['Education'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Education_count.index,Education_count.values)
plt.xlabel('Education')
plt.ylabel('count')
plt.title('Distribution of Education')
plt.show()

# %%
# count number of Marital_status
Marital_status_count=df3['Marital_status'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Marital_status_count.index,Marital_status_count.values)
plt.xlabel('Marital_status')
plt.ylabel('count')
plt.title('Distribution of Marital_status')
plt.show()

# %%
# count number of Housing_type
Housing_type_count=df3['Housing_type'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Housing_type_count.index,Housing_type_count.values)
plt.xlabel('Housing_type')
plt.ylabel('count')
plt.title('Distribution of Housing_type')
plt.show()
# most of the customer prefer two own there aprtment

# %%
# count number of Employed_days
Employed_days_count=df3['Employed_exp'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(15,5))
plt.bar(Employed_days_count.index,Employed_days_count.values)
plt.xlabel('Employed_exp')
plt.ylabel('count')
plt.title('Distribution of Employed_exp')
plt.show()

# %%
# count number of Mobile_phone
Mobile_phone_count=df3['Mobile_phone'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Mobile_phone_count.index,Mobile_phone_count.values)
plt.xlabel('Mobile_phone')
plt.ylabel('count')
plt.title('Distribution of Mobile_phone')
plt.show()

# %%
# count number of Type_Occupation
Type_Occupation_count=df3['Type_Occupation'].value_counts()
#creat barpolt using Matplotlib
plt.figure(figsize=(30,10))
plt.bar(Type_Occupation_count.index,Type_Occupation_count.values)
plt.xlabel('Type_Occupation')
plt.ylabel('count')
plt.title('Distribution of Type_Occupation')
plt.show()

# %%
# count number of Family_Members
Family_Members_count=df3['Family_Members'].value_counts()
#creat barpolt using Matplotlib
plt.bar(Family_Members_count.index,Family_Members_count.values)
plt.xlabel('Family_Members')
plt.ylabel('count')
plt.title('Distribution of Family_Members')
plt.show()

# %%
# removing columns which of No use
df3 = df3.drop(['Ind_id', 'Mobile_phone','Work_Phone','Phone','Email_id'], axis=1)

# %%
df3.head(7)
# Out:
#   Gender Car_Owner Propert_Owner  Children Annual_income  \
# 0      M         Y             Y         0      180000.0
# 1      F         Y             N         0      315000.0
# 2      F         Y             N         0      315000.0
# 3      F         Y             N         0        135000
# 4      F         Y             N         0      315000.0
# 5      F         Y             N         0      315000.0
# 6      F         Y             N         0      315000.0
#
#             Type_Income         Education Marital_status Housing_type   Age  \
# 0             Pensioner  Higher education        Married    apartment  51.0
# 1  Commercial associate  Higher education        Married    apartment  37.0
# 2  Commercial associate  Higher education        Married    apartment    42
# 3  Commercial associate  Higher education        Married    apartment  37.0
# 4  Commercial associate  Higher education        Married    apartment  37.0
# ...

# %% [markdown]
# # Lebel encoding

# %%
#applying the lebel encoding 
custom_mappings = {
    'Gender':{'M': 0,'F':1},
    'Car_Owner':{'Y':0,'N':1},
    'Propert_Owner':{'Y':0,'N':1},
    'Type_Income': {'Pensioner': 0, 'Commercial associate': 1,'Working': 2,'State servant':3},
    'Education': {'Higher education': 0, 'Secondary education': 1,'Lower secondary': 2,'Incomplete higher': 3,'Academic degree':4},
    'Marital_status': {'Married': 0, 'Single': 1,},
    'Housing_type': {'apartment': 0, 'Rented apartment': 1,},
    'Type_Occupation': {'lower_staff': 0, 'Core staff': 1,'Cooking staff':2,'Sales staff': 3,'Accountants': 4,'High skill tech staff': 5,'Higher_manager_level': 6,'IT staff': 7,'Medicine staff': 8,'Private service staff': 9,'Realty agents':10},
    
}

# %%
df3.replace(custom_mappings, inplace=True)
df3.head()
# Out:
#    Gender  Car_Owner  Propert_Owner  Children Annual_income  Type_Income  \
# 0       0          0              0         0      180000.0            0
# 1       1          0              1         0      315000.0            1
# 2       1          0              1         0      315000.0            1
# 3       1          0              1         0        135000            1
# 4       1          0              1         0      315000.0            1
#
#    Education  Marital_status  Housing_type   Age  Employed_exp  \
# 0          0               0             0  51.0           0.0
# 1          0               0             0  37.0           2.0
# 2          0               0             0    42           2.0
# 3          0               0             0  37.0           2.0
# 4          0               0             0  37.0           2.0
#
#    Type_Occupation  Family_Members  label
# 0                0               2      1
# 1                0               2      1
# ...

# %% [markdown]
# # Feature Selection chi-square Test

# %%
df3.boxplot(figsize=(19, 9))
plt.title('Box plot for DataFrame df3')
plt.show()
#model cotain sum outliner values

# %% [markdown]
# ## Model Selection

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df3[['Gender','Car_Owner','Propert_Owner','Children','Annual_income','Type_Income','Education','Marital_status','Housing_type','Age','Employed_exp','Type_Occupation','Family_Members']],
                                              df3['label'],test_size=0.3,random_state=40)

# %%
## Perform chi2 test
### Fscore and the pvalue
from sklearn.feature_selection import chi2
f_p_values=chi2(X_train,y_train)

# %%
# count the number rows and columns for x_test
X_test.shape
# Out:
# (465, 13)

# %%
# count the number rows and columns for x_train
X_train.shape
# Out:
# (1083, 13)

# %%
# count the number rows for y_test
y_test.shape
# Out:
# (465,)

# %%
# count the number rows for y_train
y_train.shape
# Out:
# (1083,)

# %%
f_p_values
# Out:
# (array([1.56692919e-01, 5.66732443e-01, 3.76904532e-04, 1.07935966e+00,
#         7.83442562e+03, 4.58298163e+00, 5.45810279e-04, 2.63387831e+00,
#         1.81998820e+01, 6.97628563e+00, 1.01041346e+02, 2.31108706e+00,
#         6.22794873e-01]),
#  array([6.92219699e-01, 4.51560286e-01, 9.84510819e-01, 2.98840848e-01,
#         0.00000000e+00, 3.22909803e-02, 9.81361051e-01, 1.04605916e-01,
#         1.98891160e-05, 8.25968629e-03, 9.00833125e-24, 1.28454187e-01,
#         4.30010586e-01]))

# %%
import pandas as pd
p_values=pd.Series(f_p_values[1])
p_values.index=X_train.columns
p_values
# Out:
# Gender             6.922197e-01
# Car_Owner          4.515603e-01
# Propert_Owner      9.845108e-01
# Children           2.988408e-01
# Annual_income      0.000000e+00
# Type_Income        3.229098e-02
# Education          9.813611e-01
# Marital_status     1.046059e-01
# Housing_type       1.988912e-05
# Age                8.259686e-03
# Employed_exp       9.008331e-24
# Type_Occupation    1.284542e-01
# Family_Members     4.300106e-01
# dtype: float64

# %%
plt.figure(figsize=(20, 8))
sns.heatmap(df3.corr(),annot=True);
#only the annual income contain direct relation with the terget varible 
# rest all contain inverse relation with the terget varible

# %% [markdown]
# # Scaling

# %%
# importing the MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
rescale_X_train = scaler.fit_transform(X_train)
rescale_X_test = scaler.fit_transform(X_test)
print(rescale_X_train.shape)
print(rescale_X_test.shape)
# Out:
# (1083, 13)
# (465, 13)

# %% [markdown]
# ### Applying ML algorithm to the pre-processed columns and find out, which of these algorithms is best suitable.

# %% [markdown]
# ## Logistic Regression

# %%
##Logistic Regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Select relevant columns for predictor variables (X) and target variable (y)
X = df3[['Gender','Car_Owner','Propert_Owner','Children','Annual_income','Type_Income','Education','Marital_status','Housing_type','Age','Employed_exp','Type_Occupation','Family_Members']]
y = df3['label']

# %%
model = LogisticRegression()

# Fit the model on the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
classification_report_output = classification_report(y_test, y_pred)
confusion_matrix_output = confusion_matrix(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print('Classification Report:\n', classification_report_output)
print('Confusion Matrix:\n', confusion_matrix_output)
# Out:
# Accuracy: 0.886021505376344
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       412
#            1       0.00      0.00      0.00        53
#
#     accuracy                           0.89       465
#    macro avg       0.44      0.50      0.47       465
# weighted avg       0.79      0.89      0.83       465
#
# Confusion Matrix:
#  [[412   0]
#  [ 53   0]]

# %% [markdown]
# ##  Dicision Tree

# %%
# decision tree classification  without rescaled
from sklearn.tree import DecisionTreeClassifier
classification = DecisionTreeClassifier()
classification = classification.fit(X_train,y_train)
y_pred = classification.predict(X_test)
print("decision tree training set:",classification.score(X_train, y_train))
print("decision tree testing set:",classification.score(X_test, y_test))
print("Accuracy:", accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# decision tree training set: 0.9926131117266851
# decision tree testing set: 0.832258064516129
# Accuracy: 0.832258064516129
# [[362  50]
#  [ 28  25]]

# %% [markdown]
# ## cross validation¶

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model= DecisionTreeClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.85806452 0.83548387 0.86451613 0.85806452 0.85483871 0.83225806
#  0.8516129  0.83870968 0.82903226 0.85483871]
# 0.8477419354838709

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
print("rf training set:",rf.score(X_train, y_train))
print("rf testing set:",rf.score(X_test, y_test))
print("Random Forest classifier has accuracy of: ", rf.score(X_test, y_test))
# Evaluate the confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# rf training set: 0.9927302100161551
# rf testing set: 0.932258064516129
# Random Forest classifier has accuracy of:  0.932258064516129
# [[279   1]
#  [ 20  10]]

# %% [markdown]
# ## Cross validation

# %%
# cross validation
from sklearn.model_selection import ShuffleSplit
model=RandomForestClassifier()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,X,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.90322581 0.92043011 0.90967742 0.89677419 0.90107527 0.92258065
#  0.93548387 0.92688172 0.92688172 0.91612903]
# 0.9159139784946237

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import ShuffleSplit, cross_val_score
import numpy as np

# Assuming X and y are your feature matrix and target variable
# Replace these with your actual data


# Create a RandomForestClassifier model
model = RandomForestClassifier()

# Create a ShuffleSplit cross-validation splitter
ssplit = ShuffleSplit(n_splits=10, test_size=0.3, random_state=42)

# Perform cross-validation and get accuracy scores
results = cross_val_score(model, X, y, cv=ssplit)

# Print individual accuracy scores
print("Accuracy Scores:", results)

# Print the mean accuracy
print("Mean Accuracy:", np.mean(results))
# Out:
# Accuracy Scores: [0.93548387 0.90322581 0.93333333 0.91397849 0.91182796 0.92258065
#  0.92903226 0.91397849 0.92043011 0.91397849]
# Mean Accuracy: 0.919784946236559

# %% [markdown]
# ### Conclusion

# %% [markdown]
# conclusion
# Hence we got accuracy on different classification
#
# -logisitic regression got accuracy 88%
#
# -DecisionTree got accuracy 85%
#
# -Random Forest got accuracy 92%
#
# -Cross validation got accuracy 91%
#
# we have done all the elementry EDA steps needed and plotted various graphs to determine the correlation among the independent variables and also between the independent and dependent variable.
#
# After feature selection we used four machine learning models and achieved quite good accuracy 92% in Random Forest for predicting the credit card approval.

# %%
import duckdb
import pandas as pd
conn=duckdb.connect()

conn.register('df4',df4)

# %%
query = '''
SELECT Type_Income, AVG(Annual_income) AS average_annual_income, ROW_NUMBER() OVER (ORDER BY Type_Income) AS row_id
FROM df4
GROUP BY Type_Income;
'''
result = conn.execute(query).fetchall()
print(result)
# Out:
# ---------------------------------------------------------------------------
# BinderException                           Traceback (most recent call last)
# Cell In[136], line 6
#       1 query = '''
#       2 SELECT Type_Income, AVG(Annual_income) AS average_annual_income, ROW_NUMBER() OVER (ORDER BY Type_Income) AS row_id
#       3 FROM df4
#       4 GROUP BY Type_Income;
#       5 '''
# ----> 6 result = conn.execute(query).fetchall()
#       7 print(result)
#
# BinderException: Binder Error: No function matches the given name and argument types 'avg(VARCHAR)'. You might need to add explicit type casts.
# 	Candidate functions:
# 	avg(DECIMAL) -> DECIMAL
# 	avg(SMALLINT) -> DOUBLE
# 	avg(INTEGER) -> DOUBLE
# 	avg(BIGINT) -> DOUBLE
# 	avg(HUGEINT) -> DOUBLE
# 	avg(DOUBLE) -> DOUBLE
#
# LINE 2: SELECT Type_Income, AVG(Annual_income) AS average_annual_i...
#                             ^

# %%
df4
# Out:
#        Ind_id Gender Car_Owner Propert_Owner  Children Annual_income  \
# 0     5008827      M         Y             Y         0      180000.0
# 1     5009744      F         Y             N         0      315000.0
# 2     5009746      F         Y             N         0      315000.0
# 3     5009749      F         Y             N         0        135000
# 4     5009752      F         Y             N         0      315000.0
# ...       ...    ...       ...           ...       ...           ...
# 1543  5028645      F         N             Y         0        135000
# 1544  5023655      F         N             N         0      225000.0
# 1545  5115992      M         Y             Y         2      180000.0
# 1546  5118219      M         Y             N         0      270000.0
# 1547  5053790      F         Y             Y         0      225000.0
#
#                Type_Income            Education Marital_status Housing_type  \
# ...

# %%
import duckdb
import pandas as pd

# Assuming df4 is your DataFrame
conn = duckdb.connect()
conn.register('df4', df4)

# Write the SQL query
query = """
SELECT Type_Income, AVG(Annual_income) AS Average_Annual_Income
FROM df4
GROUP BY Type_Income;
"""

# Execute the query and fetch the result
result = conn.execute(query).fetch_df()

# Display the result
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 # Assuming df4 is your DataFrame
#       5 conn = duckdb.connect()
# ----> 6 conn.register('df4', df4)
#       8 # Write the SQL query
#       9 query = """
#      10 SELECT Type_Income, AVG(Annual_income) AS Average_Annual_Income
#      11 FROM df4
#      12 GROUP BY Type_Income;
#      13 """
#
# NameError: name 'df4' is not defined
